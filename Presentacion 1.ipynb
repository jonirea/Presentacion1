# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./data/top100.csv")

# %%
df.sort_values(by=['popularity'], ascending=False)
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 2                Mood (feat. iann dior)       24kGoldn
# 1                      Watermelon Sugar   Harry Styles
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 2                    cali rap  2021                91      72            70
# ...

# %%
top_artists = df["artist"].value_counts().head(10).to_frame()
top_artists
# Out:
#                   artist
# Post Malone            7
# Ed Sheeran             5
# The Weeknd             4
# Imagine Dragons        4
# Shawn Mendes           3
# Billie Eilish          3
# Maroon 5               3
# The Chainsmokers       3
# Justin Bieber          3
# Travis Scott           2

# %%
top_artists['Index'] = range(0, 0+len(top_artists))

top_artists = top_artists.reset_index().set_index('Index')

top_artists = top_artists.rename(columns = {"index" : "Artist", "artist" : "Contador"})

# %%
artists = top_artists["Artist"]

app = top_artists["Contador"]

plt.rcParams["figure.figsize"] = (15,5)

plt.subplot().set_title('Artistas Top', fontsize = 25)

plt.xticks(fontsize = 10, rotation=-20)

plt.yticks(fontsize =8)

plt.bar(artists, app)

plt.xlabel("Artistas", fontsize = 15)

plt.ylabel("Numero de canciones en el top 100", fontsize = 15)

plt.show()

# %%
top_genres = df["top genre"].value_counts().head(10).to_frame()
top_genres
# Out:
#                            top genre
# dance pop                         28
# pop                               11
# dfw rap                            7
# modern rock                        6
# canadian pop                       6
# canadian contemporary r&b          4
# electropop                         4
# melodic rap                        3
# latin                              2
# folk-pop                           2

# %%
top_genres['Index'] = range(0, 0+len(top_artists))

top_genres = top_genres.reset_index().set_index('Index')

top_genres = top_genres.rename(columns = {"index" : "Genre", "top genre" : "Contador"})

# %%
genres = top_genres["Genre"]

app = top_genres["Contador"]

plt.rcParams["figure.figsize"] = (15,5)

plt.subplot().set_title("Generos Top", fontsize = 20)

plt.bar(genres, app)

plt.yticks(fontsize = 8)

plt.xticks(fontsize = 10, rotation=-75)

plt.xlabel("Genero", fontsize = 15)

plt.ylabel("Numero de canciones en el top 100", fontsize = 15)

plt.show()

# %%
plt.figure(figsize=(10,8))
color = np.random.randint(0,4,100)
df["peso"] = df["popularity"].apply(lambda x: 40 if x < 80 else 70)
plt.scatter(df["danceability"], df["popularity"],c=color,s=df["peso"])
plt.title("Estado de animo", fontsize = 30)
plt.ylabel("Popularidad")
plt.xlabel("Bailabilidad")
plt.minorticks_on()
plt.show()
